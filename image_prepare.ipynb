# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Initialize 
import glob
import os
import pandas as pd
from PIL import Image
import numpy as np
import multiprocessing
import cv2

pd.set_option('display.max_colwidth', None)
output_base = 'AGI_OA_3RDF_P1_threshold'

# ch1 - DAPI, ch2 - IBA1, ch3 - Brightfield, ch4 - BODIPY, ch5 - EEA1 
base_path = 'AGI_OA_3RDF_P1__2025-03-26T11_37_33-Measurement_1' 
full_path = glob.glob(os.path.join(base_path, '**/r*c*f*p*-ch*sk*fk*fl*/*.tiff'), recursive=True)

full_path_pd = pd.DataFrame(full_path, columns=['path'])
full_path_pd = full_path_pd[full_path_pd['path'].str.endswith('.tiff')].reset_index(drop=True)
print('In total:', full_path_pd.shape[0])

# print sample path
if full_path_pd.shape[0] > 0:
    print('Sample path:', full_path_pd.loc[0, 'path'])
# Out:
# In total: 292905
# Sample path: AGI_OA_3RDF_P1__2025-03-26T11_37_33-Measurement_1/test/r04c05f23p01-ch2sk1fk1fl1/r04c05f23p01-ch2sk1fk1fl1_Cell_6.tiff

# %%
import pandas as pd
import numpy as np
import re

# Extract row ID (e.g., 'r02') from the file path
def extract_row(path):
    match = re.search(r'r\d{2}', path)
    return match.group() if match else None

# Extract column ID (e.g., 'c05') from the file path
def extract_column(path):
    match = re.search(r'c\d{2}', path)
    return match.group() if match else None

# Add 'row' and 'column' columns to the DataFrame
full_path_pd['row'] = full_path_pd['path'].apply(extract_row)
full_path_pd['column'] = full_path_pd['path'].apply(extract_column)

# Drop any rows with missing row/column info
full_path_pd = full_path_pd.dropna(subset=['row', 'column']).reset_index(drop=True)

# Create composite keys (e.g., 'c05r02')
full_path_pd['col_row'] = full_path_pd['column'] + full_path_pd['row']

# Use the full dataset
final_sample_df = full_path_pd.copy()

# Output basic info about the data
print(f"Total samples: {final_sample_df.shape[0]}")
print(f"Included rows: {sorted(final_sample_df['row'].unique())}")
print(f"Included columns: {sorted(final_sample_df['column'].unique())}")
# Out:
# Total samples: 292905
# Included rows: ['r02', 'r03', 'r04', 'r05', 'r06', 'r07']
# Included columns: ['c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09', 'c10', 'c11']

# %%
# basic data cleaning
# Convert 1080x1080 TIFF images to 540x540 PNGs using percentile normalization
for i in range(final_sample_df.shape[0]):
    path = final_sample_df.loc[i, 'path']
    
    # Load the image in original depth (16-bit grayscale)
    im = cv2.imread(path, -1)
    
    # Resize to 540x540
    im = cv2.resize(im, (540, 540))

    # Percentile-based intensity clipping (to remove outliers)
    low, high = np.percentile(im, (0, 99.6))
    im = np.clip(im, low, high)
    
    # Normalize pixel values to the 16-bit range
    norm = (im - im.min()) * 65535.0 / (im.max() - im.min() + 1e-8)

    # Build relative path to preserve folder structure
    rel_path = os.path.relpath(path, base_path)  # e.g., r02c02.../filename.tiff
    rel_path = rel_path.replace('.tiff', '.png')
    output_path = os.path.join(output_base, rel_path)

    # Create the output directory if it doesn't exist
    output_dir = os.path.dirname(output_path)
    os.makedirs(output_dir, exist_ok=True)

    # Save the PNG as 16-bit image
    cv2.imwrite(output_path, norm.astype(np.uint16))

    # Print progress every 1000 files
    if i % 1000 == 0:
        print(f'Progress: {i}/{final_sample_df.shape[0]}')

print('Processing complete.')
# Out:
# Progress: 0/292905
# Progress: 1000/292905
# Progress: 2000/292905
# Progress: 3000/292905
# Progress: 4000/292905
# Progress: 5000/292905
# Progress: 6000/292905
# Progress: 7000/292905
# Progress: 8000/292905
# Progress: 9000/292905
# Progress: 10000/292905
# Progress: 11000/292905
# Progress: 12000/292905
# Progress: 13000/292905
# Progress: 14000/292905
# Progress: 15000/292905
# Progress: 16000/292905
# Progress: 17000/292905
# Progress: 18000/292905
# Progress: 19000/292905
# Progress: 20000/292905
# Progress: 21000/292905
# Progress: 22000/292905
# Progress: 23000/292905
# Progress: 24000/292905
# Progress: 25000/292905
# Progress: 26000/292905
# Progress: 27000/292905
# Progress: 28000/292905
# Progress: 29000/292905
# Progress: 30000/292905
# Progress: 31000/292905
# Progress: 32000/292905
# Progress: 33000/292905
# Progress: 34000/292905
# Progress: 35000/292905
# Progress: 36000/292905
# Progress: 37000/292905
# Progress: 38000/292905
# Progress: 39000/292905
# Progress: 40000/292905
# Progress: 41000/292905
# Progress: 42000/292905
# Progress: 43000/292905
# Progress: 44000/292905
# Progress: 45000/292905
# Progress: 46000/292905
# Progress: 47000/292905
# Progress: 48000/292905
# Progress: 49000/292905
# Progress: 50000/292905
# Progress: 51000/292905
# Progress: 52000/292905
# Progress: 53000/292905
# Progress: 54000/292905
# Progress: 55000/292905
# Progress: 56000/292905
# Progress: 57000/292905
# Progress: 58000/292905
# Progress: 59000/292905
# Progress: 60000/292905
# Progress: 61000/292905
# Progress: 62000/292905
# Progress: 63000/292905
# Progress: 64000/292905
# Progress: 65000/292905
# Progress: 66000/292905
# Progress: 67000/292905
# Progress: 68000/292905
# Progress: 69000/292905
# Progress: 70000/292905
# Progress: 71000/292905
# Progress: 72000/292905
# Progress: 73000/292905
# Progress: 74000/292905
# Progress: 75000/292905
# Progress: 76000/292905
# Progress: 77000/292905
# Progress: 78000/292905
# Progress: 79000/292905
# Progress: 80000/292905
# Progress: 81000/292905
# Progress: 82000/292905
# Progress: 83000/292905
# Progress: 84000/292905
# Progress: 85000/292905
# Progress: 86000/292905
# Progress: 87000/292905
# Progress: 88000/292905
# Progress: 89000/292905
# Progress: 90000/292905
# Progress: 91000/292905
# Progress: 92000/292905
# Progress: 93000/292905
# Progress: 94000/292905
# Progress: 95000/292905
# Progress: 96000/292905
# Progress: 97000/292905
# Progress: 98000/292905
# Progress: 99000/292905
# Progress: 100000/292905
# Progress: 101000/292905
# Progress: 102000/292905
# Progress: 103000/292905
# Progress: 104000/292905
# Progress: 105000/292905
# Progress: 106000/292905
# Progress: 107000/292905
# Progress: 108000/292905
# Progress: 109000/292905
# Progress: 110000/292905
# Progress: 111000/292905
# Progress: 112000/292905
# Progress: 113000/292905
# Progress: 114000/292905
# Progress: 115000/292905
# Progress: 116000/292905
# Progress: 117000/292905
# Progress: 118000/292905
# Progress: 119000/292905
# Progress: 120000/292905
# Progress: 121000/292905
# Progress: 122000/292905
# Progress: 123000/292905
# Progress: 124000/292905
# Progress: 125000/292905
# Progress: 126000/292905
# Progress: 127000/292905
# Progress: 128000/292905
# Progress: 129000/292905
# Progress: 130000/292905
# Progress: 131000/292905
# Progress: 132000/292905
# Progress: 133000/292905
# Progress: 134000/292905
# Progress: 135000/292905
# Progress: 136000/292905
# Progress: 137000/292905
# Progress: 138000/292905
# Progress: 139000/292905
# Progress: 140000/292905
# Progress: 141000/292905
# Progress: 142000/292905
# Progress: 143000/292905
# Progress: 144000/292905
# Progress: 145000/292905
# Progress: 146000/292905
# Progress: 147000/292905
# Progress: 148000/292905
# Progress: 149000/292905
# Progress: 150000/292905
# Progress: 151000/292905
# Progress: 152000/292905
# Progress: 153000/292905
# Progress: 154000/292905
# Progress: 155000/292905
# Progress: 156000/292905
# Progress: 157000/292905
# Progress: 158000/292905
# Progress: 159000/292905
# Progress: 160000/292905
# Progress: 161000/292905
# Progress: 162000/292905
# Progress: 163000/292905
# Progress: 164000/292905
# Progress: 165000/292905
# Progress: 166000/292905
# Progress: 167000/292905
# Progress: 168000/292905
# Progress: 169000/292905
# Progress: 170000/292905
# Progress: 171000/292905
# Progress: 172000/292905
# Progress: 173000/292905
# Progress: 174000/292905
# Progress: 175000/292905
# Progress: 176000/292905
# Progress: 177000/292905
# Progress: 178000/292905
# Progress: 179000/292905
# Progress: 180000/292905
# Progress: 181000/292905
# Progress: 182000/292905
# Progress: 183000/292905
# Progress: 184000/292905
# Progress: 185000/292905
# Progress: 186000/292905
# Progress: 187000/292905
# Progress: 188000/292905
# Progress: 189000/292905
# Progress: 190000/292905
# Progress: 191000/292905
# Progress: 192000/292905
# Progress: 193000/292905
# Progress: 194000/292905
# Progress: 195000/292905
# Progress: 196000/292905
# Progress: 197000/292905
# Progress: 198000/292905
# Progress: 199000/292905
# Progress: 200000/292905
# Progress: 201000/292905
# Progress: 202000/292905
# Progress: 203000/292905
# Progress: 204000/292905
# Progress: 205000/292905
# Progress: 206000/292905
# Progress: 207000/292905
# Progress: 208000/292905
# Progress: 209000/292905
# Progress: 210000/292905
# Progress: 211000/292905
# Progress: 212000/292905
# Progress: 213000/292905
# Progress: 214000/292905
# Progress: 215000/292905
# Progress: 216000/292905
# Progress: 217000/292905
# Progress: 218000/292905
# Progress: 219000/292905
# Progress: 220000/292905
# Progress: 221000/292905
# Progress: 222000/292905
# Progress: 223000/292905
# Progress: 224000/292905
# Progress: 225000/292905
# Progress: 226000/292905
# Progress: 227000/292905
# Progress: 228000/292905
# Progress: 229000/292905
# Progress: 230000/292905
# Progress: 231000/292905
# Progress: 232000/292905
# Progress: 233000/292905
# Progress: 234000/292905
# Progress: 235000/292905
# Progress: 236000/292905
# Progress: 237000/292905
# Progress: 238000/292905
# Progress: 239000/292905
# Progress: 240000/292905
# Progress: 241000/292905
# Progress: 242000/292905
# Progress: 243000/292905
# Progress: 244000/292905
# Progress: 245000/292905
# Progress: 246000/292905
# Progress: 247000/292905
# Progress: 248000/292905
# Progress: 249000/292905
# Progress: 250000/292905
# Progress: 251000/292905
# Progress: 252000/292905
# Progress: 253000/292905
# Progress: 254000/292905
# Progress: 255000/292905
# Progress: 256000/292905
# Progress: 257000/292905
# Progress: 258000/292905
# Progress: 259000/292905
# Progress: 260000/292905
# Progress: 261000/292905
# Progress: 262000/292905
# Progress: 263000/292905
# Progress: 264000/292905
# Progress: 265000/292905
# Progress: 266000/292905
# Progress: 267000/292905
# Progress: 268000/292905
# Progress: 269000/292905
# Progress: 270000/292905
# Progress: 271000/292905
# Progress: 272000/292905
# Progress: 273000/292905
# Progress: 274000/292905
# Progress: 275000/292905
# Progress: 276000/292905
# Progress: 277000/292905
# Progress: 278000/292905
# Progress: 279000/292905
# Progress: 280000/292905
# Progress: 281000/292905
# Progress: 282000/292905
# Progress: 283000/292905
# Progress: 284000/292905
# Progress: 285000/292905
# Progress: 286000/292905
# Progress: 287000/292905
# Progress: 288000/292905
# Progress: 289000/292905
# Progress: 290000/292905
# Progress: 291000/292905
# Progress: 292000/292905
# Processing complete.

# %%
import os
import pandas as pd

# Make sure final_sample_df already exists and includes a 'path' column
final_sample_df = final_sample_df.reset_index(drop=True)

# Extract the base filename (remove suffixes like '_Cell_1')
final_sample_df['filename'] = final_sample_df['path'].apply(lambda x: os.path.basename(x).split('_')[0])

# Extract row, column, field, plane, and channel information
final_sample_df['row'] = final_sample_df['filename'].str[0:3]        # e.g., r07
final_sample_df['column'] = final_sample_df['filename'].str[3:6]     # e.g., c08
final_sample_df['field'] = final_sample_df['filename'].str[6:9]      # e.g., f11
final_sample_df['plane'] = final_sample_df['filename'].str[9:12]     # e.g., p01
final_sample_df['channel'] = final_sample_df['filename'].str[13:16]  # e.g., ch1

# Construct compound identifiers like rcf and rc to support group analysis
final_sample_df['rcf'] = final_sample_df['row'] + final_sample_df['column'] + final_sample_df['field']
final_sample_df['rc'] = final_sample_df['row'] + final_sample_df['column']
final_sample_df['front'] = final_sample_df['filename'].str[:-7]

# Keep only images with plane == 'p03'
final_sample_df = final_sample_df[final_sample_df['plane'] == 'p03'].reset_index(drop=True)

# Output basic info of the filtered dataset
print(f"Total number of filtered images: {final_sample_df.shape[0]}")
print(f"Included rows: {sorted(final_sample_df['row'].unique())}")
print(f"Included columns: {sorted(final_sample_df['column'].unique())}")
print(f"Included fields: {sorted(final_sample_df['field'].unique())}")
print(f"Included channels: {sorted(final_sample_df['channel'].unique())}")

# Sort by rcf, plane, and channel
final_sample_df = final_sample_df.sort_values(by=['rcf', 'plane', 'channel']).reset_index(drop=True)

# Show the first few rows
final_sample_df.head()
# Out:
# Total number of filtered images: 104405
# Included rows: ['r02', 'r03', 'r04', 'r05', 'r06', 'r07']
# Included columns: ['c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09', 'c10', 'c11']
# Included fields: ['f01', 'f02', 'f03', 'f04', 'f05', 'f06', 'f07', 'f08', 'f09', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29', 'f30', 'f31', 'f32', 'f33', 'f34']
# Included channels: ['ch1', 'ch2', 'ch3', 'ch4', 'ch5']
#                                                                                                                       path  \
# 0  AGI_OA_3RDF_P1__2025-03-26T11_37_33-Measurement_1/test/r02c02f01p03-ch1sk1fk1fl1/r02c02f01p03-ch1sk1fk1fl1_Cell_13.tiff
# 1   AGI_OA_3RDF_P1__2025-03-26T11_37_33-Measurement_1/test/r02c02f01p03-ch1sk1fk1fl1/r02c02f01p03-ch1sk1fk1fl1_Cell_9.tiff
# 2  AGI_OA_3RDF_P1__2025-03-26T11_37_33-Measurement_1/test/r02c02f01p03-ch1sk1fk1fl1/r02c02f01p03-ch1sk1fk1fl1_Cell_29.tiff
# 3   AGI_OA_3RDF_P1__2025-03-26T11_37_33-Measurement_1/test/r02c02f01p03-ch1sk1fk1fl1/r02c02f01p03-ch1sk1fk1fl1_Cell_5.tiff
# 4  AGI_OA_3RDF_P1__2025-03-26T11_37_33-Measurement_1/test/r02c02f01p03-ch1sk1fk1fl1/r02c02f01p03-ch1sk1fk1fl1_Cell_33.tiff
#
#    row column col_row                   filename field plane channel  \
# 0  r02    c02  c02r02  r02c02f01p03-ch1sk1fk1fl1   f01   p03     ch1
# 1  r02    c02  c02r02  r02c02f01p03-ch1sk1fk1fl1   f01   p03     ch1
# 2  r02    c02  c02r02  r02c02f01p03-ch1sk1fk1fl1   f01   p03     ch1
# 3  r02    c02  c02r02  r02c02f01p03-ch1sk1fk1fl1   f01   p03     ch1
# 4  r02    c02  c02r02  r02c02f01p03-ch1sk1fk1fl1   f01   p03     ch1
#
#          rcf      rc               front
# 0  r02c02f01  r02c02  r02c02f01p03-ch1sk
# 1  r02c02f01  r02c02  r02c02f01p03-ch1sk
# 2  r02c02f01  r02c02  r02c02f01p03-ch1sk
# 3  r02c02f01  r02c02  r02c02f01p03-ch1sk
# 4  r02c02f01  r02c02  r02c02f01p03-ch1sk

# %%
import os
import numpy as np
import cv2
from pathlib import Path

# Updated Helen's thresholds for all 5 channels
thres_dict = {
    'ch1': [520, 3200],
    'ch2': [1000, 5800],
    'ch3': [2200, 3400],
    'ch4': [500, 6000],
    'ch5': [450, 6500],
}

# Output base folder
output_base = 'AGI_OA_3RDF_P1_threshold'

# Process each channel separately
for i_ch in np.sort(final_sample_df['channel'].unique()):
    if i_ch not in thres_dict:
        print(f"Skipping unknown channel: {i_ch}")
        continue

    temp_img_path = final_sample_df[final_sample_df['channel'] == i_ch].reset_index(drop=True)

    for i in range(temp_img_path.shape[0]):
        path = temp_img_path.loc[i, 'path']
        im = cv2.imread(path, -1)
        im = cv2.resize(im, (540, 540))

        # Apply Helen's channel-specific threshold
        low, high = thres_dict[i_ch]
        im[im > high] = im.min()
        im = np.clip(im, low, high)

        # Further percentile clipping to remove extremes
        low_p, high_p = np.percentile(im, (0, 99.6))
        if low_p != high_p:
            im = np.clip(im, low_p, high_p)

        # Normalize to 16-bit range
        norm = (im - im.min()) * 65535.0 / (im.max() - im.min() + 1e-8)

        # Construct relative output path
        rel_path = os.path.relpath(path, base_path).replace('.tiff', '.png')
        output_path = os.path.join(output_base, rel_path)

        # Make sure the output directory exists
        os.makedirs(os.path.dirname(output_path), exist_ok=True)

        # Save as 16-bit PNG
        cv2.imwrite(output_path, norm.astype(np.uint16))

        if i % 1000 == 0:
            print(f'Progress ({i_ch}): {i}/{temp_img_path.shape[0]}')

print('All channels processed.')
# Out:
# Progress (ch1): 0/20881
# Progress (ch1): 1000/20881
# Progress (ch1): 2000/20881
# Progress (ch1): 3000/20881
# Progress (ch1): 4000/20881
# Progress (ch1): 5000/20881
# Progress (ch1): 6000/20881
# Progress (ch1): 7000/20881
# Progress (ch1): 8000/20881
# Progress (ch1): 9000/20881
# Progress (ch1): 10000/20881
# Progress (ch1): 11000/20881
# Progress (ch1): 12000/20881
# Progress (ch1): 13000/20881
# Progress (ch1): 14000/20881
# Progress (ch1): 15000/20881
# Progress (ch1): 16000/20881
# Progress (ch1): 17000/20881
# Progress (ch1): 18000/20881
# Progress (ch1): 19000/20881
# Progress (ch1): 20000/20881
# Progress (ch2): 0/20881
# Progress (ch2): 1000/20881
# Progress (ch2): 2000/20881
# Progress (ch2): 3000/20881
# Progress (ch2): 4000/20881
# Progress (ch2): 5000/20881
# Progress (ch2): 6000/20881
# Progress (ch2): 7000/20881
# Progress (ch2): 8000/20881
# Progress (ch2): 9000/20881
# Progress (ch2): 10000/20881
# Progress (ch2): 11000/20881
# Progress (ch2): 12000/20881
# Progress (ch2): 13000/20881
# Progress (ch2): 14000/20881
# Progress (ch2): 15000/20881
# Progress (ch2): 16000/20881
# Progress (ch2): 17000/20881
# Progress (ch2): 18000/20881
# Progress (ch2): 19000/20881
# Progress (ch2): 20000/20881
# Progress (ch3): 0/20881
# Progress (ch3): 1000/20881
# Progress (ch3): 2000/20881
# Progress (ch3): 3000/20881
# Progress (ch3): 4000/20881
# Progress (ch3): 5000/20881
# Progress (ch3): 6000/20881
# Progress (ch3): 7000/20881
# Progress (ch3): 8000/20881
# Progress (ch3): 9000/20881
# Progress (ch3): 10000/20881
# Progress (ch3): 11000/20881
# Progress (ch3): 12000/20881
# Progress (ch3): 13000/20881
# Progress (ch3): 14000/20881
# Progress (ch3): 15000/20881
# Progress (ch3): 16000/20881
# Progress (ch3): 17000/20881
# Progress (ch3): 18000/20881
# Progress (ch3): 19000/20881
# Progress (ch3): 20000/20881
# Progress (ch4): 0/20881
# Progress (ch4): 1000/20881
# Progress (ch4): 2000/20881
# Progress (ch4): 3000/20881
# Progress (ch4): 4000/20881
# Progress (ch4): 5000/20881
# Progress (ch4): 6000/20881
# Progress (ch4): 7000/20881
# Progress (ch4): 8000/20881
# Progress (ch4): 9000/20881
# Progress (ch4): 10000/20881
# Progress (ch4): 11000/20881
# Progress (ch4): 12000/20881
# Progress (ch4): 13000/20881
# Progress (ch4): 14000/20881
# Progress (ch4): 15000/20881
# Progress (ch4): 16000/20881
# Progress (ch4): 17000/20881
# Progress (ch4): 18000/20881
# Progress (ch4): 19000/20881
# Progress (ch4): 20000/20881
# Progress (ch5): 0/20881
# Progress (ch5): 1000/20881
# Progress (ch5): 2000/20881
# Progress (ch5): 3000/20881
# Progress (ch5): 4000/20881
# Progress (ch5): 5000/20881
# Progress (ch5): 6000/20881
# Progress (ch5): 7000/20881
# Progress (ch5): 8000/20881
# Progress (ch5): 9000/20881
# Progress (ch5): 10000/20881
# Progress (ch5): 11000/20881
# Progress (ch5): 12000/20881
# Progress (ch5): 13000/20881
# Progress (ch5): 14000/20881
# Progress (ch5): 15000/20881
# Progress (ch5): 16000/20881
# Progress (ch5): 17000/20881
# Progress (ch5): 18000/20881
# Progress (ch5): 19000/20881
# Progress (ch5): 20000/20881
# All channels processed.

# %%
import os
import shutil

# Set the base directory where your folders are stored
base_dir = 'AGI_OA_3RDF_P1_threshold/test'

# Get all folder names
all_folders = [f for f in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, f))]

# Loop through and delete folders not containing 'p03' in the correct position
for folder in all_folders:
    # Check if 'p03' appears in the standard position (should be around 11th–14th char)
    if 'p03' not in folder:
        folder_path = os.path.join(base_dir, folder)
        print(f"Deleting: {folder_path}")
        shutil.rmtree(folder_path)

print("Only p03 folders remain.")
# Out:
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f23p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f07p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c04f34p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f26p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f34p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f11p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c10f10p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f14p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c06f23p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f15p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f26p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f29p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f28p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f14p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f04p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f16p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f19p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f32p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f18p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f01p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f13p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f24p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f25p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f19p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f21p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f16p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f20p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c10f20p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f01p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f13p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f15p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f14p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f02p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c06f23p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f28p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f29p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f26p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f07p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f26p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f23p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c10f10p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f31p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f26p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f34p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f11p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f20p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f21p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f16p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f21p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f01p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f13p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f32p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f18p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f01p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f04p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f19p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f16p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f25p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f16p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f01p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f13p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f18p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f24p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f32p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f07p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f07p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f02p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f29p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f32p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f32p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f29p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f02p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f07p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f10p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f09p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c09f07p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f22p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f11p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c04f09p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f27p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f14p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f27p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f22p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f29p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f15p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f29p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f28p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f27p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f19p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f24p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f32p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f18p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f17p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f24p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f25p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f12p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f21p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f17p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f20p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f17p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f12p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f22p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f15p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f14p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f28p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f27p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f28p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f22p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f29p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c09f07p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f11p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f22p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f09p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f27p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f11p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f17p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f20p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f21p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f12p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f12p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f32p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f17p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f18p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f19p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f25p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f25p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f12p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f24p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f33p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f11p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f06p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f14p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f03p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f21p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f33p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f03p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f11p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f06p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f17p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f05p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f12p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f22p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f09p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f09p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f30p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f27p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f27p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f30p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f05p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f05p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f12p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f17p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f30p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f27p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f09p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f22p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f34p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f11p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f28p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f14p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f09p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f22p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f11p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f26p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f28p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f27p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f14p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f14p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c09f01p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f17p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f24p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f16p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f21p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f18p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f17p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f24p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f12p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f21p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f18p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f24p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f27p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f28p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f11p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f26p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f11p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f14p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f28p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f22p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f34p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f11p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f22p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f14p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f09p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f12p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f21p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f24p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f18p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f21p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c09f01p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f18p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f24p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f17p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f18p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f01p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f16p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f21p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f01p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f04p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f34p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f08p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f34p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f31p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f04p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f01p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f01p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f31p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f08p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f34p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f29p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f07p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c09f09p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f02p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f10p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f23p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f10p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f09p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f15p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f22p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f26p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f29p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f27p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f10p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f27p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f31p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f29p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f07p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f15p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f01p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f20p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f25p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f16p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f19p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f17p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f12p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f19p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f04p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f25p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f19p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f13p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f20p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c06f32p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f31p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f27p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f10p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f29p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f26p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f26p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f07p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f15p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f31p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f02p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f10p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f29p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f15p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f15p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f22p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f23p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f09p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f12p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f25p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f20p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c06f32p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f12p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f19p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f25p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f01p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f32p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f17p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f19p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f16p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f25p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f22p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f15p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f08p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f10p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f23p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f10p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f29p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f15p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f29p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f30p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f27p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f10p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f27p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c09f30p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f29p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f26p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f17p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f20p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f19p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f16p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f25p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f20p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f20p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c09f05p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f19p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f25p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f19p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c09f12p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f13p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f15p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f26p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f30p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f26p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f29p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f10p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f27p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f23p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f22p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f15p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f08p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f08p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f15p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f29p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f10p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f19p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f12p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f20p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c09f05p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f13p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f05p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f25p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c09f12p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f25p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f16p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f19p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f17p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f20p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f25p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f01p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f13p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f04p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f34p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f23p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f23p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f08p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f34p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f26p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f13p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f04p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f16p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f01p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f01p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f26p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f34p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f08p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f23p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f22p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c04f06p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f14p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f23p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f28p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f23p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f03p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f11p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f30p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f06p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f14p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f14p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f27p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f28p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f26p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f03p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f11p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f17p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f18p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c06f21p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f16p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f24p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f17p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f24p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f05p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f18p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f21p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f33p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c10f12p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f13p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f24p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f06p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f14p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f30p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f26p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f03p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f11p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f28p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f27p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c04f06p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f14p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f28p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f23p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f22p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f03p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f11p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c10f22p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f28p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f21p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f05p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f18p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f13p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f24p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f21p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c10f12p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c06f21p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f16p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f18p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f17p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f24p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f18p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f16p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f05p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f09p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f09p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f30p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f30p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f05p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f05p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f30p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f09p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f33p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f18p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f06p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f03p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f03p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f28p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f18p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f33p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f18p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f28p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f03p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f06p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f27p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f10p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f22p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f10p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f28p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f30p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f29p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f03p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f15p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f30p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f27p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f14p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f12p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f33p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f25p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f24p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f05p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f17p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f18p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f24p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f33p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f19p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f12p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f17p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f20p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f17p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f21p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f29p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f22p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f03p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f28p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f28p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f14p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f15p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f30p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f27p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f10p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f22p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f11p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f05p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f12p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f12p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f21p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f20p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f17p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f24p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f12p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f25p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f25p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f33p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f19p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f05p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f18p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f17p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f07p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f07p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f10p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f15p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f02p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f25p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f32p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f15p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f02p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f07p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f10p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f23p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f10p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f26p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f08p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f23p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f14p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f28p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f29p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f26p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c09f03p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f15p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f03p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f23p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f14p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f19p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f25p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f24p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f13p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f18p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f13p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f33p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f16p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f13p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f20p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f20p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f16p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f21p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f26p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f29p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c09f03p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f08p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f15p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f28p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f23p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f14p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f15p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f26p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f10p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f23p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f08p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f13p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c09f21p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f16p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f21p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f20p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f24p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f18p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f13p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f16p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f25p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f33p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f16p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f18p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c06f29p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f34p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f08p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f02p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f02p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f09p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f07p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c09f22p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f29p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f02p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f31p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f30p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f07p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f01p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f32p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f19p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f32p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f17p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f12p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f04p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f19p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f05p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f32p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f02p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f29p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f30p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f07p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f31p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f02p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f09p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c06f29p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f34p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f07p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f07p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c09f22p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f09p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c06f19p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f12p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f04p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f05p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f32p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f04p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f19p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f01p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f32p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f17p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f19p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f01p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f16p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f01p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f04p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f13p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f23p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f26p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f04p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f13p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f01p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f26p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f23p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f34p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f23p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f22p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f34p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f11p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f03p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f09p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f06p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c09f08p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f22p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f03p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f27p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f06p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f14p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c06f06p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f31p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f30p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f11p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f01p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f33p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f21p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f17p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f01p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f24p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f12p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f33p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f04p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f05p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f27p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f14p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f03p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f30p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f03p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f14p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c06f06p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f31p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f34p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f11p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f03p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c09f08p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f34p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f22p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f06p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f09p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f12p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f33p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f24p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f05p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f33p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f04p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f01p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f17p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f17p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f33p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f21p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f17p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f12p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f12p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f22p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f09p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f27p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f12p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f17p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f27p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f27p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f09p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f22p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f09p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f24p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f18p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f18p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f21p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f21p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f11p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f28p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f14p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f21p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f24p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f18p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f14p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f28p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f14p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f11p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f09p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f06p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f07p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f30p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c04f22p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c10f06p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f27p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f09p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f30p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f22p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f03p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f29p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f27p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f02p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f33p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f32p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f17p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f32p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c06f12p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c06f17p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f05p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f05p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f12p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f30p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f22p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f09p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f27p02-ch2sk1fk1fl1
# ...
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f05p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c06f17p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f21p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f05p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f32p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f05p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f12p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c06f30p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f11p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f27p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f09p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f06p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f07p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f22p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f30p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f03p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f29p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f14p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f09p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f02p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f09p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f22p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f30p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c04f17p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f19p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f32p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f05p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f21p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f05p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c06f17p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f21p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f18p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f24p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f28p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f14p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f28p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f11p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f11p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f18p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f24p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f24p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f21p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f11p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f14p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f28p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f31p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f02p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f34p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f29p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f08p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f14p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f31p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f06p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f34p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f08p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f11p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c09f11p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f08p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f07p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f06p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f01p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c06f01p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c09f21p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f04p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f01p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f32p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f32p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f04p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f34p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f07p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f11p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f06p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f07p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f08p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f34p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f29p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f02p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f14p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f31p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f29p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f34p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c07f08p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f01p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c08f33p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f04p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f32p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f24p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f01p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c05f04p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c09f21p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f04p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f20p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f19p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f32p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f25p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f02p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f15p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f29p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f15p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f07p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f10p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f32p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f19p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f19p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f25p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f20p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c03f07p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f10p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f15p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f29p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f13p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f01p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f16p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f26p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f31p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f31p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f26p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f34p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f23p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c03f01p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c03f16p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f04p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c03f13p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f13p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f34p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c02f23p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c02f26p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c02f31p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f07p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f02p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f31p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c09f27p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f02p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f29p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f08p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f07p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f09p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f02p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f34p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f22p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c06f29p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f05p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f19p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f04p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f12p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f32p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f32p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f01p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f17p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c04f19p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f01p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f09p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c04f07p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f08p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f29p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f34p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f34p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c06f29p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c07f02p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c11f31p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c07f07p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c06f07p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f29p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c09f27p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c04f02p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c04f19p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c05f32p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c08f17p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c10f01p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f19p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f19p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f04p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c08f05p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c08f12p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f12p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f17p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f27p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f22p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f09p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f22p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f17p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c02f17p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c02f12p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c03f22p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c02f09p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c03f27p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f06p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f14p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f31p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f27p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f31p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f03p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c06f11p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f08p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f22p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f06p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f09p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c04f06p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f34p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c06f03p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f11p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f05p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f21p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f33p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f12p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f04p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f12p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f24p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c10f05p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f17p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f21p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f33p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f01p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c11f09p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c05f06p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c09f08p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f03p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c10f22p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c08f34p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c06f03p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c05f11p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f14p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c10f09p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c06f06p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f14p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c08f31p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f03p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c06f11p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c11f30p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c10f27p01-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c07f21p02-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c04f33p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c05f24p02-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c11f17p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r03c09f01p02-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c05f33p01-ch1sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c04f21p01-ch5sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r04c07f33p01-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r02c09f04p02-ch2sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r05c11f05p01-ch3sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r07c07f24p02-ch4sk1fk1fl1
# Deleting: AGI_OA_3RDF_P1_threshold/test/r06c11f12p02-ch3sk1fk1fl1
# Only p03 folders remain.
